# %%
"""
  Estimates the total amount of scope 1 emissions per year given
  the type and amount of fuel that company vehicles use and the
  number of vehicles the company owns.  

  (explain the thing here)

  Assumes that each company vehicle drives 40k miles/year and
  travels 30 miles per gallon. (explain the 18.74 lbs co2e 
  thing here and why we're assuming this)

  Total scope 1 emissions per year equals the sum of the
  emissions from fuel and from the vehicles.

  Input:
    fuel_type: type of fuel that company vehicles use. either 'coal,'
               'diesel,' 'gasoline,' 'propane,' or 'natural gas'
    fuel_amount: decimal value represeting # of millions of Btu of fuel
    company_vehicles: number of company vehicles
  
  Output:
    total_scope_one: estimate of total scope 1 emissions per year.
"""
def scope_one(fuel_type, fuel_amount, company_vehicles):
  fuel_types = ['coal', 'diesel', 'gasoline', 'propane', 'natural gas']

  #can you explain what these three lines of code do in the header lol
  fuel_emissions = [210,161,157,139,117] #lbs co2e per million Btu of fuel
  fuel_index = fuel_types.index(fuel_type)
  fuel_emissions = fuel_amount * fuel_emissions[fuel_index]

  #assume 40k miles/year, 30 mpg. known 18.74 lbs co2e per gallon gasoline
  vehicle_emissions = company_vehicles * 40000 / 30 * 18.74 
  
  total_scope_one = fuel_emissions + vehicle_emissions
  return total_scope_one

print(scope_one('coal',100,1000))
# Out:
# 25007666.666666664

# %%
def scope_two():
  return total_scope_two
